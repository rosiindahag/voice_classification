# %% [markdown]
# ## Import Data

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error, r2_score
from math import sqrt
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
import matplotlib.pyplot as plt
import pickle

# %%
train_data = pd.read_csv('data_training_80.csv',)
test_data = pd.read_csv('data_testing_20.csv',)
train_data
# Out:
#      musicId         1         2         3         4         5         6  \
# 0        115  0.810309  0.652040  0.352955  0.479980  0.624326  0.506090
# 1        273  0.611423  0.725266  0.482102  0.735999  0.587029  0.576044
# 2        443  0.655093  0.635506  0.586567  0.592474  0.630387  0.541304
# 3        670  0.726366  0.594337  0.617652  0.737579  0.445268  0.626910
# 4        974  0.847067  0.658698  0.444569  0.894559  0.543543  0.756289
# ..       ...       ...       ...       ...       ...       ...       ...
# 609      964  0.722996  0.634191  0.482973  0.456483  0.665312  0.556162
# 610      646  0.822002  0.674689  0.252225  0.472317  0.605404  0.291542
# 611     1000  0.849100  0.386121  0.389046  0.859937  0.244877  0.609949
# 612      916  0.506600  0.487193  0.852309  0.700500  0.751951  0.630006
# 613       18  0.765652  0.648192  0.265034  0.447387  0.491202  0.416057
#
#             7         8         9  ...        45        46        47  \
# 0    0.354364  0.379702  0.332710  ...  0.806559  0.574075  0.548951
# 1    0.698031  0.335977  0.557596  ...  0.849521  0.632599  0.651982
# 2    0.614534  0.208019  0.413907  ...  0.491389  0.412280  0.272645
# 3    0.742325  0.456851  0.500371  ...  0.501652  0.571458  0.479365
# 4    0.549201  0.244741  0.393812  ...  0.887410  0.669736  0.599487
# ..        ...       ...       ...  ...       ...       ...       ...
# 609  0.693902  0.393010  0.198990  ...  0.447569  0.393278  0.479711
# 610  0.355218  0.537804  0.317161  ...  0.526169  0.354195  0.459944
# 611  0.681721  0.125022  0.561609  ...  0.532813  0.631663  0.616928
# 612  0.689053  0.684641  0.676407  ...  0.576699  0.361473  0.334266
# 613  0.425836  0.242767  0.396412  ...  0.433820  0.462429  0.840823
#
#            48        49        50        51        52  arousal(mean)  \
# 0    0.543246  0.395771  0.508903  0.466953  0.683918         0.8000
# 1    0.767750  0.711006  0.758799  0.676016  0.676017         0.3375
# 2    0.454392  0.557033  0.615091  0.729049  0.433594         0.7000
# 3    0.420058  0.453907  0.649287  0.744141  0.642224         0.3500
# 4    0.781159  0.514321  0.514228  0.470437  0.556135         0.6250
# ..        ...       ...       ...       ...       ...            ...
# 609  0.561614  0.506092  0.822221  0.606376  0.647613         0.5375
# 610  0.370234  0.484749  0.558287  0.468069  0.617637         0.8625
# 611  0.705317  0.548085  0.548629  0.596983  0.411173         0.6625
# 612  0.350365  0.386151  0.440258  0.581891  0.710342         0.2125
# 613  0.545953  0.380119  0.741288  0.472440  0.207695         0.8000
#
#      valence(mean)
# 0           0.8000
# 1           0.3625
# 2           0.6750
# 3           0.4250
# 4           0.5875
# ..             ...
# 609         0.6000
# 610         0.7875
# 611         0.5750
# 612         0.3375
# 613         0.8375
#
# [614 rows x 55 columns]

# %%
train_data = np.array(train_data)
test_data = np.array(test_data)
#the number of columns
len_data = np.size(train_data,axis=1)
train_data
# Out:
# array([[1.15000000e+02, 8.10309070e-01, 6.52039758e-01, ...,
#         6.83918098e-01, 8.00000000e-01, 8.00000000e-01],
#        [2.73000000e+02, 6.11423363e-01, 7.25266033e-01, ...,
#         6.76016765e-01, 3.37500000e-01, 3.62500000e-01],
#        [4.43000000e+02, 6.55092529e-01, 6.35506451e-01, ...,
#         4.33593686e-01, 7.00000000e-01, 6.75000000e-01],
#        ...,
#        [1.00000000e+03, 8.49100044e-01, 3.86121496e-01, ...,
#         4.11173394e-01, 6.62500000e-01, 5.75000000e-01],
#        [9.16000000e+02, 5.06600324e-01, 4.87192805e-01, ...,
#         7.10342212e-01, 2.12500000e-01, 3.37500000e-01],
#        [1.80000000e+01, 7.65651798e-01, 6.48191888e-01, ...,
#         2.07694543e-01, 8.00000000e-01, 8.37500000e-01]])

# %%
#separate musicId, features, arousal(mean), valence(mean) in training data
musicId_train = np.int_(train_data[:,0:1])
features_train = train_data[:,1:len_data-2]
number_of_features = np.size(features_train[0],axis=0)
arousal_mean_train = train_data[:,len_data-2]
valence_mean_train = train_data[:,len_data-1]

# %%
musicId_train[0]
# Out:
# array([115])

# %%
#separate musicId, features, arousal(mean), valence(mean) in testing data
musicId_test = np.int_(test_data[:,0:1])
features_test = test_data[:,1:len_data-2]
number_of_features = np.size(features_test[0],axis=0)
arousal_mean_test = test_data[:,len_data-2]
valence_mean_test = test_data[:,len_data-1]

# %%
arousal_mean_train[0]
# Out:
# 0.8

# %%
valence_mean_train[0]
# Out:
# 0.8

# %% [markdown]
# ## Regression

# %% [markdown]
# #### Linear Regression for Multioutput Regression

# %%
X = features_train
y = train_data[:,len_data-2:len_data]
linear_model = LinearRegression()
linear_model.fit(X, y)
ypred_linear = linear_model.predict(features_train)
# print(ypred_linear)

# %%
yactual_train = train_data[:,len_data-2:len_data]

# %% [markdown]
# #### k-Nearest Neighbors for Multioutput Regression

# %%
knn_model = KNeighborsRegressor(n_neighbors=5)
knn_model.fit(X, y)
ypred_knn = knn_model.predict(features_train)

# %% [markdown]
# #### Decision Tree for Multioutput Regression

# %%
dectree_model = DecisionTreeRegressor()
dectree_model.fit(X, y)
ypred_dectree = dectree_model.predict(features_train)

# %% [markdown]
# ## Evaluating

# %%
linear_mse = mean_squared_error(yactual_train, ypred_linear)
knn_mse = mean_squared_error(yactual_train, ypred_knn)
dectree_mse = mean_squared_error(yactual_train, ypred_dectree)
linear_rmse = sqrt(linear_mse)
knn_rmse = sqrt(knn_mse)
dectree_rmse = sqrt(dectree_mse)
print("RMSE linear regression: "+str(linear_rmse))
print("RMSE knn regression: "+str(knn_rmse))
print("RMSE decision tree regression: "+str(dectree_rmse))
# Out:
# RMSE linear regression: 0.12264186502851492
# RMSE knn regression: 0.12633227681958384
# RMSE decision tree regression: 0.007770141684134912

# %%
r2_linear_train = r2_score(yactual_train,ypred_linear)
r2_knn_train = r2_score(yactual_train, ypred_knn)
r2_dectree_train = r2_score(yactual_train, ypred_dectree)
print("R2 linear regression: "+str(r2_linear_train))
print("R2 knn regression: "+str(r2_knn_train))
print("R2 decision tree regression: "+str(r2_dectree_train))
# Out:
# R2 linear regression: 0.4755156019584039
# R2 knn regression: 0.44923542513291964
# R2 decision tree regression: 0.9977731476780144

# %%
ytrain_pred = pd.DataFrame(yactual_train)
ytrain_pred["pred_lin_aro(mean)"]=ypred_linear[:,0]
ytrain_pred["pred_lin_val(mean)"]=ypred_linear[:,1]
ytrain_pred["pred_knn_aro(mean)"]=ypred_knn[:,0]
ytrain_pred["pred_knn_val(mean)"]=ypred_knn[:,1]
ytrain_pred["pred_dectree_aro(mean)"]=ypred_dectree[:,0]
ytrain_pred["pred_dectree_val(mean)"]=ypred_dectree[:,1]
ytrain_pred
# Out:
#           0       1  pred_lin_aro(mean)  pred_lin_val(mean)  \
# 0    0.8000  0.8000            0.730207            0.654862
# 1    0.3375  0.3625            0.432514            0.433677
# 2    0.7000  0.6750            0.721429            0.720763
# 3    0.3500  0.4250            0.420488            0.491099
# 4    0.6250  0.5875            0.627435            0.585164
# ..      ...     ...                 ...                 ...
# 609  0.5375  0.6000            0.573483            0.587059
# 610  0.8625  0.7875            0.666502            0.610511
# 611  0.6625  0.5750            0.758809            0.718326
# 612  0.2125  0.3375            0.309368            0.396797
# 613  0.8000  0.8375            0.647147            0.688174
#
#      pred_knn_aro(mean)  pred_knn_val(mean)  pred_dectree_aro(mean)  \
# 0                0.7300              0.7050                  0.8000
# 1                0.3225              0.3200                  0.3375
# 2                0.6075              0.6200                  0.7000
# 3                0.4400              0.5375                  0.3500
# 4                0.5825              0.5700                  0.6250
# ..                  ...                 ...                     ...
# 609              0.5900              0.6150                  0.5375
# 610              0.7600              0.7000                  0.8625
# 611              0.6175              0.5125                  0.6625
# 612              0.3525              0.5175                  0.2125
# 613              0.6425              0.7425                  0.8000
#
#      pred_dectree_val(mean)
# 0                    0.8000
# 1                    0.3625
# 2                    0.6750
# 3                    0.4250
# 4                    0.5875
# ..                      ...
# 609                  0.6000
# 610                  0.7875
# 611                  0.5750
# 612                  0.3375
# 613                  0.8375
#
# [614 rows x 8 columns]

# %%
#cek persebaran data
plt.xlim(0,1)
plt.ylim(0,1)
plt.axhline(y=0.5, color='black', linestyle='-')
plt.axvline(x=0.5, color='black', linestyle='-')
plt.xlabel("Arousal(mean)")
plt.ylabel("Valence(mean)")
plt.scatter(yactual_train[:,0],yactual_train[:,1])

plt.show()

# %% [markdown]
# ### save model

# %%
pickle.dump(linear_model, open('linear_model_mean.sav', 'wb'))
pickle.dump(knn_model, open('knn_model_mean.sav', 'wb'))
pickle.dump(dectree_model, open('dectree_model_mean.sav', 'wb'))

# %% [markdown]
# ### load model

# %%
yactual_test = test_data[:,len_data-2:len_data]

# %%
loaded_model_linear = pickle.load(open('linear_model_mean.sav', 'rb'))
loaded_model_knn = pickle.load(open('knn_model_mean.sav', 'rb'))
loaded_model_dectree = pickle.load(open('dectree_model_mean.sav', 'rb'))
# result = loaded_model_linear.score(features_test,yactual_test)
# print(result)

# %%
yactual_test
# Out:
# array([[0.6125    , 0.5375    ],
#        [0.8625    , 0.7875    ],
#        [0.65      , 0.7125    ],
#        [0.3125    , 0.3       ],
#        [0.6875    , 0.675     ],
#        [0.7625    , 0.7375    ],
#        [0.4375    , 0.425     ],
#        [0.6375    , 0.5625    ],
#        [0.875     , 0.59090909],
#        [0.775     , 0.6125    ],
#        [0.7875    , 0.7375    ],
#        [0.5875    , 0.6375    ],
#        [0.525     , 0.3625    ],
#        [0.8875    , 0.8125    ],
#        [0.7125    , 0.775     ],
#        [0.2375    , 0.275     ],
#        [0.8375    , 0.9125    ],
#        [0.8       , 0.7       ],
#        [0.7       , 0.5625    ],
#        [0.4375    , 0.3625    ],
#        [0.4125    , 0.45      ],
#        [0.6125    , 0.3125    ],
#        [0.7375    , 0.725     ],
#        [0.675     , 0.65      ],
#        [0.51136364, 0.38636364],
#        [0.5125    , 0.5875    ],
#        [0.7375    , 0.675     ],
#        [0.225     , 0.3       ],
#        [0.375     , 0.4625    ],
#        [0.3       , 0.425     ],
#        [0.8       , 0.6       ],
#        [0.55      , 0.425     ],
#        [0.6125    , 0.525     ],
#        [0.4       , 0.4625    ],
#        [0.8375    , 0.475     ],
#        [0.375     , 0.6625    ],
#        [0.4875    , 0.4125    ],
#        [0.8875    , 0.85      ],
#        [0.65      , 0.55      ],
#        [0.275     , 0.3375    ],
#        [0.225     , 0.3625    ],
#        [0.4375    , 0.4375    ],
#        [0.45      , 0.3375    ],
#        [0.575     , 0.45      ],
#        [0.8375    , 0.75      ],
#        [0.3625    , 0.2625    ],
#        [0.9       , 0.475     ],
#        [0.6625    , 0.7875    ],
#        [0.6375    , 0.575     ],
#        [0.825     , 0.6375    ],
#        [0.825     , 0.8875    ],
#        [0.45      , 0.325     ],
#        [0.5375    , 0.65      ],
#        [0.625     , 0.7       ],
#        [0.875     , 0.675     ],
#        [0.4625    , 0.4625    ],
#        [0.4       , 0.6125    ],
#        [0.79545455, 0.75      ],
#        [0.7625    , 0.7625    ],
#        [0.85      , 0.775     ],
#        [0.3625    , 0.7375    ],
#        [0.86363636, 0.75      ],
#        [0.55      , 0.5125    ],
#        [0.325     , 0.6125    ],
#        [0.3375    , 0.325     ],
#        [0.55      , 0.475     ],
#        [0.7625    , 0.5375    ],
#        [0.5125    , 0.5       ],
#        [0.6875    , 0.8375    ],
#        [0.25      , 0.4875    ],
#        [0.2       , 0.3875    ],
#        [0.4       , 0.575     ],
#        [0.525     , 0.4875    ],
#        [0.925     , 0.625     ],
#        [0.825     , 0.7125    ],
#        [0.8875    , 0.875     ],
#        [0.775     , 0.6875    ],
#        [0.875     , 0.5625    ],
#        [0.425     , 0.375     ],
#        [0.7625    , 0.725     ],
#        [0.2625    , 0.225     ],
#        [0.6625    , 0.65      ],
#        [0.25      , 0.35      ],
#        [0.6       , 0.6125    ],
#        [0.6375    , 0.2       ],
#        [0.675     , 0.675     ],
#        [0.8875    , 0.8375    ],
#        [0.57954545, 0.54545455],
#        [0.7       , 0.725     ],
#        [0.7375    , 0.7125    ],
#        [0.725     , 0.65      ],
#        [0.7375    , 0.6625    ],
#        [0.725     , 0.825     ],
#        [0.6375    , 0.775     ],
#        [0.4375    , 0.5       ],
#        [0.7875    , 0.7125    ],
#        [0.15      , 0.2       ],
#        [0.5625    , 0.6125    ],
#        [0.8       , 0.75      ],
#        [0.4125    , 0.35      ],
#        [0.325     , 0.525     ],
#        [0.7125    , 0.5625    ],
#        [0.5125    , 0.7625    ],
#        [0.375     , 0.6375    ],
#        [0.3375    , 0.625     ],
#        [0.8       , 0.7       ],
#        [0.65      , 0.5375    ],
#        [0.775     , 0.6       ],
#        [0.8       , 0.5875    ],
#        [0.8       , 0.775     ],
#        [0.9       , 0.7875    ],
#        [0.575     , 0.6625    ],
#        [0.8       , 0.6625    ],
#        [0.675     , 0.5375    ],
#        [0.45      , 0.35      ],
#        [0.2875    , 0.4875    ],
#        [0.8625    , 0.825     ],
#        [0.8375    , 0.825     ],
#        [0.9375    , 0.7875    ],
#        [0.8375    , 0.75      ],
#        [0.5125    , 0.375     ],
#        [0.575     , 0.575     ],
#        [0.625     , 0.6125    ],
#        [0.85      , 0.7375    ],
#        [0.7375    , 0.7625    ],
#        [0.7       , 0.4875    ],
#        [0.675     , 0.625     ],
#        [0.675     , 0.2125    ],
#        [0.4625    , 0.3       ],
#        [0.6       , 0.6       ],
#        [0.7375    , 0.825     ],
#        [0.6125    , 0.7       ],
#        [0.7625    , 0.8125    ],
#        [0.4125    , 0.5       ],
#        [0.825     , 0.8625    ],
#        [0.7       , 0.55      ],
#        [0.6875    , 0.6125    ],
#        [0.5875    , 0.6875    ],
#        [0.8625    , 0.725     ],
#        [0.825     , 0.7625    ],
#        [0.6375    , 0.6125    ],
#        [0.9375    , 0.9125    ],
#        [0.75      , 0.625     ],
#        [0.35      , 0.5125    ],
#        [0.5375    , 0.525     ],
#        [0.6       , 0.5875    ],
#        [0.675     , 0.6875    ],
#        [0.2375    , 0.7375    ],
#        [0.275     , 0.35      ],
#        [0.5875    , 0.775     ],
#        [0.7875    , 0.775     ],
#        [0.8625    , 0.6875    ],
#        [0.325     , 0.25      ]])

# %%
ypred_test_linear = loaded_model_linear.predict(features_test)
ypred_test_knn = loaded_model_knn.predict(features_test)
ypred_test_dectree = loaded_model_dectree.predict(features_test)

# %%
linear_mse = mean_squared_error(yactual_test, ypred_test_linear)
knn_mse = mean_squared_error(yactual_test, ypred_test_knn)
dectree_mse = mean_squared_error(yactual_test, ypred_test_dectree)
linear_rmse = sqrt(linear_mse)
knn_rmse = sqrt(knn_mse)
dectree_rmse = sqrt(dectree_mse)
print("RMSE linear regression: "+str(linear_rmse))
print("RMSE knn regression: "+str(knn_rmse))
print("RMSE decision tree regression: "+str(dectree_rmse))
# Out:
# RMSE linear regression: 0.14093380462981744
# RMSE knn regression: 0.16652056876478416
# RMSE decision tree regression: 0.22085156540206807

# %%
r2_linear_test = r2_score(yactual_test,ypred_test_linear)
r2_knn_test = r2_score(yactual_test, ypred_test_knn)
r2_dectree_test = r2_score(yactual_test, ypred_test_dectree)
print("R2 linear regression: "+str(r2_linear_test))
print("R2 knn regression: "+str(r2_knn_test))
print("R2 decision tree regression: "+str(r2_dectree_test))
# Out:
# R2 linear regression: 0.39454131538871656
# R2 knn regression: 0.16869167810479258
# R2 decision tree regression: -0.32151543661651183

# %%
ytest_pred = pd.DataFrame(yactual_test)
ytest_pred["pred_lin_aro(mean)"]=ypred_test_linear[:,0]
ytest_pred["pred_lin_val(mean)"]=ypred_test_linear[:,1]
ytest_pred["pred_knn_aro(mean)"]=ypred_test_knn[:,0]
ytest_pred["pred_knn_val(mean)"]=ypred_test_knn[:,1]
ytest_pred["pred_dectree_aro(mean)"]=ypred_test_dectree[:,0]
ytest_pred["pred_dectree_val(mean)"]=ypred_test_dectree[:,1]
ytest_pred
# Out:
#           0       1  pred_lin_aro(mean)  pred_lin_val(mean)  \
# 0    0.6125  0.5375            0.636930            0.670928
# 1    0.8625  0.7875            0.798692            0.668014
# 2    0.6500  0.7125            0.719226            0.678686
# 3    0.3125  0.3000            0.377440            0.410717
# 4    0.6875  0.6750            0.648823            0.686786
# ..      ...     ...                 ...                 ...
# 148  0.2750  0.3500            0.462946            0.555670
# 149  0.5875  0.7750            0.664663            0.671783
# 150  0.7875  0.7750            0.799372            0.709554
# 151  0.8625  0.6875            0.750026            0.669939
# 152  0.3250  0.2500            0.433034            0.567397
#
#      pred_knn_aro(mean)  pred_knn_val(mean)  pred_dectree_aro(mean)  \
# 0              0.637500            0.665000                  0.8250
# 1              0.730000            0.647500                  0.7250
# 2              0.532500            0.552500                  0.2750
# 3              0.539091            0.553182                  0.6375
# 4              0.647500            0.685000                  0.7250
# ..                  ...                 ...                     ...
# 148            0.407500            0.442500                  0.7500
# 149            0.697727            0.664318                  0.5875
# 150            0.645000            0.647500                  0.6500
# 151            0.787500            0.725000                  0.3750
# 152            0.410000            0.450000                  0.3875
#
#      pred_dectree_val(mean)
# 0                    0.6625
# 1                    0.6375
# 2                    0.1375
# 3                    0.6250
# 4                    0.7500
# ..                      ...
# 148                  0.4125
# 149                  0.7500
# 150                  0.6500
# 151                  0.4000
# 152                  0.2625
#
# [153 rows x 8 columns]

# %% [markdown]
# ### Scatter plot of data testing

# %%
import matplotlib.pyplot as plt
plt.xlim(0,1)
plt.ylim(0,1)
plt.axhline(y=0.5, color='black', linestyle='-')
plt.axvline(x=0.5, color='black', linestyle='-')
plt.xlabel("Arousal(mean)")
plt.ylabel("Valence(mean)")
plt.scatter(yactual_test[:,0],yactual_test[:,1],label="actual")
plt.scatter(ypred_test_linear[:,0],ypred_test_linear[:,1],label="linear")
plt.scatter(ypred_test_knn[:,0],ypred_test_knn[:,1],label="knn")
plt.scatter(ypred_test_dectree[:,0],ypred_test_dectree[:,1],label="decision_tree")
plt.legend()
plt.show()
