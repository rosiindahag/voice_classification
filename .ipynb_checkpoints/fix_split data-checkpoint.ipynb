# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
df_vocals = pd.read_csv('raw_data.csv')
df_music = pd.read_csv('raw_data_music.csv')
df_ori = pd.read_csv('raw_data_ori.csv')
df_ori
# Out:
#      Unnamed: 0  musicId           1           2          3          4  \
# 0             0        1 -134.501938  140.709869 -33.806183  40.509468
# 1             1        4 -185.762405  150.708191  -6.543074  40.350780
# 2             2        5 -187.960785  134.830582  -3.551626  50.650608
# 3             3        6 -150.089249  133.114471 -28.649672  47.446262
# 4             4        7  -68.078255  140.158691 -30.088114  46.314041
# ..          ...      ...         ...         ...        ...        ...
# 762         762      993  -82.034897  115.693184 -27.506472  41.420624
# 763         763      996  -39.439030  117.582779 -41.585430  37.604584
# 764         764      997  -96.058891  109.789352 -29.685734  40.733002
# 765         765      999  -81.660851   87.558594 -37.968273  45.893429
# 766         766     1000  -41.221684  111.641144 -47.133541  61.363186
#
#              5          6          7          8  ...        45        46  \
# ...

# %%
del df_vocals['Unnamed: 0']
del df_music['Unnamed: 0']
del df_ori['Unnamed: 0']

# %%
df_ori
# Out:
#      musicId           1           2          3          4          5  \
# 0          1 -134.501938  140.709869 -33.806183  40.509468 -30.187325
# 1          4 -185.762405  150.708191  -6.543074  40.350780   0.332607
# 2          5 -187.960785  134.830582  -3.551626  50.650608   5.722176
# 3          6 -150.089249  133.114471 -28.649672  47.446262  -1.269912
# 4          7  -68.078255  140.158691 -30.088114  46.314041 -27.235332
# ..       ...         ...         ...        ...        ...        ...
# 762      993  -82.034897  115.693184 -27.506472  41.420624 -22.511772
# 763      996  -39.439030  117.582779 -41.585430  37.604584 -41.974018
# 764      997  -96.058891  109.789352 -29.685734  40.733002 -29.974644
# 765      999  -81.660851   87.558594 -37.968273  45.893429 -31.830296
# 766     1000  -41.221684  111.641144 -47.133541  61.363186 -33.117691
#
#              6          7          8          9  ...        45        46  \
# ...

# %%
number_of_features = np.size(df_music,axis=1)-2
number_of_features
# Out:
# 53

# %%
#only features
df_vocals.iloc[:,1:53]
df_music.iloc[:,1:53]
df_ori.iloc[:,1:53]
# Out:
#               1           2          3          4          5          6  \
# 0   -134.501938  140.709869 -33.806183  40.509468 -30.187325  18.371941
# 1   -185.762405  150.708191  -6.543074  40.350780   0.332607  14.048911
# 2   -187.960785  134.830582  -3.551626  50.650608   5.722176  26.734537
# 3   -150.089249  133.114471 -28.649672  47.446262  -1.269912  36.032425
# 4    -68.078255  140.158691 -30.088114  46.314041 -27.235332  26.583315
# ..          ...         ...        ...        ...        ...        ...
# 762  -82.034897  115.693184 -27.506472  41.420624 -22.511772  30.121929
# 763  -39.439030  117.582779 -41.585430  37.604584 -41.974018  32.544621
# 764  -96.058891  109.789352 -29.685734  40.733002 -29.974644  41.178413
# 765  -81.660851   87.558594 -37.968273  45.893429 -31.830296  33.797039
# 766  -41.221684  111.641144 -47.133541  61.363186 -33.117691  40.391724
#
#              7          8          9         10  ...        43        44  \
# ...

# %%
#normalisasi
scaler = MinMaxScaler()
df_vocals.iloc[:,1:number_of_features] = scaler.fit_transform(df_vocals.iloc[:,1:number_of_features])
df_music.iloc[:,1:number_of_features] = scaler.fit_transform(df_music.iloc[:,1:number_of_features])
df_ori.iloc[:,1:number_of_features] = scaler.fit_transform(df_ori.iloc[:,1:number_of_features])
df_ori
# Out:
#      musicId         1         2         3         4         5         6  \
# 0          1  0.604650  0.507952  0.394955  0.614218  0.318572  0.457519
# 1          4  0.465152  0.603125  0.600070  0.612588  0.742743  0.390705
# 2          5  0.459170  0.451987  0.622576  0.718345  0.817648  0.586765
# 3          6  0.562231  0.435651  0.433750  0.685444  0.720471  0.730467
# 4          7  0.785412  0.502705  0.422928  0.673818  0.359599  0.584428
# ..       ...       ...       ...       ...       ...       ...       ...
# 762      993  0.747431  0.269818  0.442351  0.623573  0.425248  0.639119
# 763      996  0.863349  0.287805  0.336427  0.584391  0.154758  0.676562
# 764      997  0.709267  0.213620  0.425955  0.616513  0.321528  0.810000
# 765      999  0.748449  0.002006  0.363641  0.669499  0.295737  0.695919
# 766     1000  0.858498  0.231247  0.294686  0.828341  0.277845  0.797842
#
#             7         8         9  ...        45        46        47  \
# ...

# %% [markdown]
# ### Split 80% train data and 20% test data

# %%
#random dataset
X_vocals = np.array(df_vocals)
X_music = np.array(df_music)
X_ori = np.array(df_ori)
np.random.shuffle(X_vocals)
np.random.shuffle(X_music)
np.random.shuffle(X_ori)
#X = X.sample(frac = 1) untuk data yang berbentuk dataframe
print(X_ori)
# Out:
# [[2.35000000e+02 5.22870704e-01 5.13165935e-01 ... 6.63131682e-01
#   4.50000000e-01 7.00000000e-01]
#  [9.38000000e+02 7.57555978e-01 3.92210348e-01 ... 6.40546139e-01
#   7.25000000e-01 7.50000000e-01]
#  [6.32000000e+02 8.56670252e-01 3.59826429e-01 ... 4.94059823e-01
#   8.62500000e-01 6.87500000e-01]
#  ...
#  [5.79000000e+02 6.42547138e-01 9.05882473e-01 ... 6.05613313e-01
#   2.62500000e-01 2.25000000e-01]
#  [6.47000000e+02 6.43827710e-01 6.49544248e-01 ... 2.61175943e-01
#   5.62500000e-01 6.12500000e-01]
#  [3.21000000e+02 6.18110801e-01 3.63243606e-01 ... 6.58689487e-01
#   6.87500000e-01 4.87500000e-01]]

# %% [markdown]
# ### Notes:
# ###### index 0 = musicId,
# ###### index 1 to 52 = features,
# ###### index 53: arousal(mean), index 54: valence(mean)

# %% [markdown]
# ### vocals split

# %%
#split data 80% for data training and 20% for data testing
train_data_vocals = X_vocals[:int(len(X_vocals)*.80+1)] #Remaining 80% to training set
test_data_vocals = X_vocal[int(len(X_vocals)*.80+1):] #Splits 20% data to test dataset
total_train_vocals = np.size(train_data_vocals,axis=0)
total_test_vocals = np.size(test_data_vocals,axis=0)
print("training data: "+str(total_train_vocals))
print("testing data: "+str(total_test_vocals))
print("total data: "+str(total_train_vocals+total_test_vocals))
# Out:
# training data: 614
# testing data: 153
# total data: 767

# %%
df_train_vocals = pd.DataFrame(train_data_vocals)
df_train_vocals[0] = np.int_(df_train_vocals[0])
df_train_vocals = df_train_vocals.rename({0: 'musicId', 53: 'arousal(mean)', 54:'valence(mean)'}, axis=1)
df_test_vocals = pd.DataFrame(test_data_vocals)
df_test_vocals[0] = np.int_(df_test_vocals[0])
df_test_vocals = df_test_vocals.rename({0: 'musicId', 53: 'arousal(mean)', 54:'valence(mean)'}, axis=1)
df_train_vocals
# Out:
#      musicId         1         2         3         4         5         6  \
# 0        115  0.810309  0.652040  0.352955  0.479980  0.624326  0.506090
# 1        273  0.611423  0.725266  0.482102  0.735999  0.587029  0.576044
# 2        443  0.655093  0.635506  0.586567  0.592474  0.630387  0.541304
# 3        670  0.726366  0.594337  0.617652  0.737579  0.445268  0.626910
# 4        974  0.847067  0.658698  0.444569  0.894559  0.543543  0.756289
# ..       ...       ...       ...       ...       ...       ...       ...
# 609      964  0.722996  0.634191  0.482973  0.456483  0.665312  0.556162
# 610      646  0.822002  0.674689  0.252225  0.472317  0.605404  0.291542
# 611     1000  0.849100  0.386121  0.389046  0.859937  0.244877  0.609949
# 612      916  0.506600  0.487193  0.852309  0.700500  0.751951  0.630006
# 613       18  0.765652  0.648192  0.265034  0.447387  0.491202  0.416057
#
#             7         8         9  ...        45        46        47  \
# ...

# %%
#save_data
df_train_vocals.to_csv("data_training_80.csv", sep=',', index=False)
df_test_vocals.to_csv("data_testing_20.csv", sep=',', index=False)

# %% [markdown]
# ### Music split

# %%
#split data 80% for data training and 20% for data testing
train_data_music = X_music[:int(len(X_music)*.80+1)] #Remaining 80% to training set
test_data_music = X_music[int(len(X_music)*.80+1):] #Splits 20% data to test dataset
total_train_music = np.size(train_data_music,axis=0)
total_test_music = np.size(test_data_music,axis=0)
print("training data: "+str(total_train_music))
print("testing data: "+str(total_test_music))
print("total data: "+str(total_train_music+total_test_music))
# Out:
# training data: 614
# testing data: 153
# total data: 767

# %%
df_train_music = pd.DataFrame(train_data_music)
df_train_music[0] = np.int_(df_train_music[0])
df_train_music = df_train_music.rename({0: 'musicId', 53: 'arousal(mean)', 54:'valence(mean)'}, axis=1)
df_test_music = pd.DataFrame(test_data_music)
df_test_music[0] = np.int_(df_test_music[0])
df_test_music = df_test_music.rename({0: 'musicId', 53: 'arousal(mean)', 54:'valence(mean)'}, axis=1)
df_train_music
# Out:
#      musicId         1         2         3         4         5         6  \
# 0        761  0.616053  0.604560  0.559233  0.540098  0.709121  0.718126
# 1        639  0.794242  0.589957  0.288092  0.688563  0.441708  0.713893
# 2        829  0.825566  0.574038  0.217420  0.618517  0.481015  0.578023
# 3        868  0.757982  0.865616  0.424191  0.410256  0.544787  0.392351
# 4        367  0.696750  0.425273  0.336051  0.606724  0.367185  0.602683
# ..       ...       ...       ...       ...       ...       ...       ...
# 609      746  0.737220  0.633805  0.452186  0.670457  0.484511  0.679158
# 610      133  0.774916  0.554481  0.333906  0.629899  0.443043  0.584161
# 611      165  0.657012  0.591013  0.278153  0.504635  0.450790  0.383903
# 612      882  0.987652  0.677162  0.150149  0.733944  0.315658  0.754086
# 613      450  0.919789  0.686858  0.187306  0.641512  0.444901  0.721218
#
#             7         8         9  ...        45        46        47  \
# ...

# %%
#save_data
df_train_music.to_csv("data_training_80_music.csv", sep=',', index=False)
df_test_music.to_csv("data_testing_20_music.csv", sep=',', index=False)

# %% [markdown]
# ### Original split

# %%
#split data 80% for data training and 20% for data testing
train_data_ori = X_ori[:int(len(X_ori)*.80+1)] #Remaining 80% to training set
test_data_ori = X_ori[int(len(X_ori)*.80+1):] #Splits 20% data to test dataset
total_train_ori = np.size(train_data_ori,axis=0)
total_test_ori = np.size(test_data_ori,axis=0)
print("training data: "+str(total_train_ori))
print("testing data: "+str(total_test_ori))
print("total data: "+str(total_train_ori+total_test_ori))
# Out:
# training data: 614
# testing data: 153
# total data: 767

# %%
df_train_ori = pd.DataFrame(train_data_ori)
df_train_ori[0] = np.int_(df_train_ori[0])
df_train_ori = df_train_ori.rename({0: 'musicId', 53: 'arousal(mean)', 54:'valence(mean)'}, axis=1)
df_test_ori = pd.DataFrame(test_data_ori)
df_test_ori[0] = np.int_(df_test_ori[0])
df_test_ori = df_test_ori.rename({0: 'musicId', 53: 'arousal(mean)', 54:'valence(mean)'}, axis=1)
df_train_ori
# Out:
#      musicId         1         2         3         4         5         6  \
# 0        235  0.522871  0.513166  0.493883  0.757369  0.784294  0.447843
# 1        938  0.757556  0.392210  0.376873  0.752740  0.383177  0.642836
# 2        632  0.856670  0.359826  0.350881  0.694302  0.463077  0.776422
# 3        312  0.887763  0.199244  0.375108  0.840503  0.399933  0.799010
# 4        139  0.740178  0.375183  0.409705  0.606704  0.535249  0.654090
# ..       ...       ...       ...       ...       ...       ...       ...
# 609      148  0.188291  0.277100  0.537817  0.627594  0.629930  0.160645
# 610      783  0.695354  0.456623  0.588107  0.667306  0.371243  0.637911
# 611      329  0.913428  0.336818  0.265755  0.633308  0.270239  0.693037
# 612      588  0.634986  0.354054  0.558577  0.702163  0.640227  0.676122
# 613      316  0.812338  0.555736  0.200240  0.734626  0.308716  0.623935
#
#             7         8         9  ...        45        46        47  \
# ...

# %%
#save_data
df_train_ori.to_csv("data_training_80_ori.csv", sep=',', index=False)
df_test_ori.to_csv("data_testing_20_ori.csv", sep=',', index=False)
