# %% [markdown]
# ## Import Data

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error, r2_score
from math import sqrt
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
import matplotlib.pyplot as plt
import pickle

# %%
train_data = pd.read_csv('data_training_80_ori.csv',)
test_data = pd.read_csv('data_testing_20_ori.csv',)
train_data
# Out:
#      musicId         1         2         3         4         5         6  \
# 0        235  0.522871  0.513166  0.493883  0.757369  0.784294  0.447843
# 1        938  0.757556  0.392210  0.376873  0.752740  0.383177  0.642836
# 2        632  0.856670  0.359826  0.350881  0.694302  0.463077  0.776422
# 3        312  0.887763  0.199244  0.375108  0.840503  0.399933  0.799010
# 4        139  0.740178  0.375183  0.409705  0.606704  0.535249  0.654090
# ..       ...       ...       ...       ...       ...       ...       ...
# 609      148  0.188291  0.277100  0.537817  0.627594  0.629930  0.160645
# 610      783  0.695354  0.456623  0.588107  0.667306  0.371243  0.637911
# 611      329  0.913428  0.336818  0.265755  0.633308  0.270239  0.693037
# 612      588  0.634986  0.354054  0.558577  0.702163  0.640227  0.676122
# 613      316  0.812338  0.555736  0.200240  0.734626  0.308716  0.623935
#
#             7         8         9  ...        45        46        47  \
# 0    0.825578  0.392659  0.645308  ...  0.669409  0.684356  0.766734
# 1    0.487821  0.607069  0.441232  ...  0.650637  0.564671  0.675219
# 2    0.503397  0.833153  0.450277  ...  0.476817  0.736219  0.476900
# 3    0.414858  0.833768  0.413735  ...  0.602408  0.630242  0.644468
# 4    0.395951  0.633198  0.514533  ...  0.673060  0.487173  0.534962
# ..        ...       ...       ...  ...       ...       ...       ...
# 609  0.638998  0.545253  0.365519  ...  0.434138  0.354041  0.303021
# 610  0.416657  0.767750  0.551217  ...  0.686244  0.527566  0.635162
# 611  0.410231  0.899185  0.386194  ...  0.452978  0.821387  0.450101
# 612  0.465038  0.662157  0.554688  ...  0.499610  0.612222  0.633841
# 613  0.371004  0.554884  0.426234  ...  0.631072  0.564467  0.516041
#
#            48        49        50        51        52  arousal(mean)  \
# 0    0.679907  0.713797  0.683607  0.644943  0.663132         0.4500
# 1    0.785958  0.630670  0.712622  0.592510  0.640546         0.7250
# 2    0.521607  0.464996  0.699678  0.851999  0.494060         0.8625
# 3    0.582730  0.628539  0.554100  0.749513  0.858815         0.8375
# 4    0.528685  0.460184  0.638967  0.548137  0.691482         0.7125
# ..        ...       ...       ...       ...       ...            ...
# 609  0.102405  0.198520  0.124897  0.371194  0.431485         0.4000
# 610  0.562611  0.536138  0.566744  0.548964  0.865322         0.4750
# 611  0.561747  0.720980  0.536196  0.810969  0.520290         0.9375
# 612  0.562819  0.659726  0.498782  0.534028  0.322283         0.7000
# 613  0.550035  0.657613  0.501833  0.597192  0.599474         0.8875
#
#      valence(mean)
# 0           0.7000
# 1           0.7500
# 2           0.6875
# 3           0.7875
# 4           0.7750
# ..             ...
# 609         0.5000
# 610         0.4500
# 611         0.7875
# 612         0.7750
# 613         0.8625
#
# [614 rows x 55 columns]

# %%
from scipy import stats
stats.ttest_ind(train_data['arousal(mean)'], train_data['valence(mean)'])
# Out:
# Ttest_indResult(statistic=2.700341485503367, pvalue=0.007022198792883757)

# %%
train_data = np.array(train_data)
test_data = np.array(test_data)
#the number of columns
len_data = np.size(train_data,axis=1)
train_data
# Out:
# array([[2.35000000e+02, 5.22870704e-01, 5.13165935e-01, ...,
#         6.63131682e-01, 4.50000000e-01, 7.00000000e-01],
#        [9.38000000e+02, 7.57555978e-01, 3.92210348e-01, ...,
#         6.40546139e-01, 7.25000000e-01, 7.50000000e-01],
#        [6.32000000e+02, 8.56670252e-01, 3.59826429e-01, ...,
#         4.94059823e-01, 8.62500000e-01, 6.87500000e-01],
#        ...,
#        [3.29000000e+02, 9.13427824e-01, 3.36818415e-01, ...,
#         5.20290422e-01, 9.37500000e-01, 7.87500000e-01],
#        [5.88000000e+02, 6.34986017e-01, 3.54053981e-01, ...,
#         3.22282913e-01, 7.00000000e-01, 7.75000000e-01],
#        [3.16000000e+02, 8.12337630e-01, 5.55735518e-01, ...,
#         5.99474044e-01, 8.87500000e-01, 8.62500000e-01]])

# %%
#separate musicId, features, arousal(mean), valence(mean) in training data
musicId_train = np.int_(train_data[:,0:1])
features_train = train_data[:,1:len_data-2]
number_of_features = np.size(features_train[0],axis=0)
arousal_mean_train = train_data[:,len_data-2]
valence_mean_train = train_data[:,len_data-1]

# %%
musicId_train[0]
# Out:
# array([235])

# %%
#separate musicId, features, arousal(mean), valence(mean) in testing data
musicId_test = np.int_(test_data[:,0:1])
features_test = test_data[:,1:len_data-2]
number_of_features = np.size(features_test[0],axis=0)
arousal_mean_test = test_data[:,len_data-2]
valence_mean_test = test_data[:,len_data-1]

# %%
arousal_mean_train[0]
# Out:
# 0.45

# %%
valence_mean_train[0]
# Out:
# 0.7

# %% [markdown]
# ## Regression

# %% [markdown]
# #### Linear Regression for Multioutput Regression

# %%
X = features_train
y = train_data[:,len_data-2:len_data]
linear_model = LinearRegression()
linear_model.fit(X, y)
ypred_linear = linear_model.predict(features_train)
# print(ypred_linear)

# %%
yactual_train = train_data[:,len_data-2:len_data]

# %% [markdown]
# #### k-Nearest Neighbors for Multioutput Regression

# %%
knn_model = KNeighborsRegressor(n_neighbors=5)
knn_model.fit(X, y)
ypred_knn = knn_model.predict(features_train)

# %% [markdown]
# #### Decision Tree for Multioutput Regression

# %%
dectree_model = DecisionTreeRegressor()
dectree_model.fit(X, y)
ypred_dectree = dectree_model.predict(features_train)

# %% [markdown]
# ## Evaluating

# %%
linear_mse = mean_squared_error(yactual_train, ypred_linear)
knn_mse = mean_squared_error(yactual_train, ypred_knn)
dectree_mse = mean_squared_error(yactual_train, ypred_dectree)
linear_rmse = sqrt(linear_mse)
knn_rmse = sqrt(knn_mse)
dectree_rmse = sqrt(dectree_mse)
print("RMSE linear regression: "+str(linear_rmse))
print("RMSE knn regression: "+str(knn_rmse))
print("RMSE decision tree regression: "+str(dectree_rmse))
# Out:
# RMSE linear regression: 0.10802728034666337
# RMSE knn regression: 0.11128495525353785
# RMSE decision tree regression: 0.007667112176075237

# %%
r2_linear_train = r2_score(yactual_train,ypred_linear)
r2_knn_train = r2_score(yactual_train, ypred_knn)
r2_dectree_train = r2_score(yactual_train, ypred_dectree)
print("R2 linear regression: "+str(r2_linear_train))
print("R2 knn regression: "+str(r2_knn_train))
print("R2 decision tree regression: "+str(r2_dectree_train))
# Out:
# R2 linear regression: 0.6030866535665615
# R2 knn regression: 0.5822183958143862
# R2 decision tree regression: 0.9979161441894395

# %%
ytrain_pred = pd.DataFrame(yactual_train)
ytrain_pred["pred_lin_aro(mean)"]=ypred_linear[:,0]
ytrain_pred["pred_lin_val(mean)"]=ypred_linear[:,1]
ytrain_pred["pred_knn_aro(mean)"]=ypred_knn[:,0]
ytrain_pred["pred_knn_val(mean)"]=ypred_knn[:,1]
ytrain_pred["pred_dectree_aro(mean)"]=ypred_dectree[:,0]
ytrain_pred["pred_dectree_val(mean)"]=ypred_dectree[:,1]
ytrain_pred
# Out:
#           0       1  pred_lin_aro(mean)  pred_lin_val(mean)  \
# 0    0.4500  0.7000            0.436009            0.463770
# 1    0.7250  0.7500            0.679995            0.641585
# 2    0.8625  0.6875            0.810553            0.707962
# 3    0.8375  0.7875            0.819159            0.744029
# 4    0.7125  0.7750            0.662757            0.590509
# ..      ...     ...                 ...                 ...
# 609  0.4000  0.5000            0.384361            0.494119
# 610  0.4750  0.4500            0.615049            0.582995
# 611  0.9375  0.7875            0.912120            0.746158
# 612  0.7000  0.7750            0.595058            0.539266
# 613  0.8875  0.8625            0.757868            0.709842
#
#      pred_knn_aro(mean)  pred_knn_val(mean)  pred_dectree_aro(mean)  \
# 0              0.570000            0.575000                  0.4500
# 1              0.747500            0.682500                  0.7250
# 2              0.867500            0.787500                  0.8625
# 3              0.864773            0.822727                  0.8375
# 4              0.682500            0.657500                  0.7125
# ..                  ...                 ...                     ...
# 609            0.387500            0.460000                  0.4000
# 610            0.730000            0.662500                  0.4750
# 611            0.890000            0.825000                  0.9375
# 612            0.727273            0.682273                  0.7000
# 613            0.765000            0.800000                  0.8875
#
#      pred_dectree_val(mean)
# 0                    0.7000
# 1                    0.7500
# 2                    0.6875
# 3                    0.7875
# 4                    0.7750
# ..                      ...
# 609                  0.5000
# 610                  0.4500
# 611                  0.7875
# 612                  0.7750
# 613                  0.8625
#
# [614 rows x 8 columns]

# %%
#cek persebaran data
plt.xlim(0,1)
plt.ylim(0,1)
plt.axhline(y=0.5, color='black', linestyle='-')
plt.axvline(x=0.5, color='black', linestyle='-')
plt.xlabel("Arousal(mean)")
plt.ylabel("Valence(mean)")
plt.scatter(yactual_train[:,0],yactual_train[:,1])

plt.show()

# %% [markdown]
# ### save model

# %%
pickle.dump(linear_model, open('linear_model_mean_ori.sav', 'wb'))
pickle.dump(knn_model, open('knn_model_mean_ori.sav', 'wb'))
pickle.dump(dectree_model, open('dectree_model_mean_ori.sav', 'wb'))

# %% [markdown]
# ### load model

# %%
yactual_test = test_data[:,len_data-2:len_data]

# %%
loaded_model_linear = pickle.load(open('linear_model_mean_music.sav', 'rb'))
loaded_model_knn = pickle.load(open('knn_model_mean_music.sav', 'rb'))
loaded_model_dectree = pickle.load(open('dectree_model_mean_music.sav', 'rb'))
# result = loaded_model_linear.score(features_test,yactual_test)
# print(result)

# %%
yactual_test
# Out:
# array([[0.6625    , 0.65      ],
#        [0.275     , 0.35      ],
#        [0.5375    , 0.8375    ],
#        [0.575     , 0.625     ],
#        [0.925     , 0.8625    ],
#        [0.4       , 0.675     ],
#        [0.5875    , 0.6875    ],
#        [0.9125    , 0.6125    ],
#        [0.6625    , 0.55      ],
#        [0.6875    , 0.725     ],
#        [0.7375    , 0.725     ],
#        [0.8125    , 0.7375    ],
#        [0.825     , 0.6875    ],
#        [0.675     , 0.575     ],
#        [0.3375    , 0.3625    ],
#        [0.725     , 0.825     ],
#        [0.8875    , 0.775     ],
#        [0.3625    , 0.5       ],
#        [0.6625    , 0.6       ],
#        [0.55      , 0.475     ],
#        [0.6       , 0.725     ],
#        [0.85      , 0.75      ],
#        [0.975     , 0.825     ],
#        [0.5625    , 0.5875    ],
#        [0.4       , 0.4625    ],
#        [0.95      , 0.8125    ],
#        [0.3875    , 0.375     ],
#        [0.5875    , 0.525     ],
#        [0.2625    , 0.2875    ],
#        [0.2625    , 0.25      ],
#        [0.7625    , 0.6       ],
#        [0.6125    , 0.725     ],
#        [0.7875    , 0.575     ],
#        [0.8375    , 0.575     ],
#        [0.5625    , 0.3625    ],
#        [0.86363636, 0.75      ],
#        [0.5875    , 0.6       ],
#        [0.8375    , 0.7875    ],
#        [0.775     , 0.65      ],
#        [0.7875    , 0.7125    ],
#        [0.7375    , 0.775     ],
#        [0.7375    , 0.6875    ],
#        [0.375     , 0.275     ],
#        [0.6125    , 0.65      ],
#        [0.675     , 0.525     ],
#        [0.7       , 0.4875    ],
#        [0.4       , 0.6125    ],
#        [0.825     , 0.8125    ],
#        [0.55681818, 0.56818182],
#        [0.6375    , 0.825     ],
#        [0.6125    , 0.625     ],
#        [0.7       , 0.5625    ],
#        [0.65      , 0.6125    ],
#        [0.7125    , 0.5625    ],
#        [0.2875    , 0.375     ],
#        [0.7875    , 0.6875    ],
#        [0.75      , 0.6875    ],
#        [0.675     , 0.675     ],
#        [0.6625    , 0.5125    ],
#        [0.6       , 0.375     ],
#        [0.8       , 0.775     ],
#        [0.45      , 0.625     ],
#        [0.7375    , 0.6875    ],
#        [0.4875    , 0.4125    ],
#        [0.5375    , 0.6625    ],
#        [0.825     , 0.725     ],
#        [0.7       , 0.6625    ],
#        [0.85      , 0.7       ],
#        [0.475     , 0.5625    ],
#        [0.575     , 0.675     ],
#        [0.3875    , 0.4       ],
#        [0.5875    , 0.6375    ],
#        [0.4875    , 0.4       ],
#        [0.6875    , 0.7       ],
#        [0.7       , 0.55      ],
#        [0.7375    , 0.7625    ],
#        [0.5875    , 0.55      ],
#        [0.2       , 0.3875    ],
#        [0.7375    , 0.675     ],
#        [0.7125    , 0.625     ],
#        [0.75      , 0.4125    ],
#        [0.9       , 0.8375    ],
#        [0.8375    , 0.75      ],
#        [0.85      , 0.725     ],
#        [0.65      , 0.5375    ],
#        [0.625     , 0.75      ],
#        [0.5875    , 0.725     ],
#        [0.6125    , 0.65      ],
#        [0.7875    , 0.8625    ],
#        [0.7       , 0.525     ],
#        [0.875     , 0.5625    ],
#        [0.7375    , 0.7125    ],
#        [0.675     , 0.475     ],
#        [0.7375    , 0.725     ],
#        [0.225     , 0.3       ],
#        [0.45      , 0.5125    ],
#        [0.7625    , 0.5375    ],
#        [0.55      , 0.55      ],
#        [0.4875    , 0.6625    ],
#        [0.8       , 0.7125    ],
#        [0.3375    , 0.3375    ],
#        [0.625     , 0.7375    ],
#        [0.6875    , 0.7375    ],
#        [0.525     , 0.4875    ],
#        [0.7125    , 0.5125    ],
#        [0.2125    , 0.3375    ],
#        [0.8125    , 0.825     ],
#        [0.675     , 0.675     ],
#        [0.3875    , 0.2625    ],
#        [0.725     , 0.7625    ],
#        [0.7125    , 0.6375    ],
#        [0.6375    , 0.2       ],
#        [0.55      , 0.4875    ],
#        [0.65      , 0.7125    ],
#        [0.9125    , 0.8125    ],
#        [0.725     , 0.725     ],
#        [0.5375    , 0.55      ],
#        [0.7125    , 0.775     ],
#        [0.7625    , 0.7625    ],
#        [0.35      , 0.3875    ],
#        [0.675     , 0.5375    ],
#        [0.5125    , 0.275     ],
#        [0.875     , 0.775     ],
#        [0.3625    , 0.4625    ],
#        [0.675     , 0.6875    ],
#        [0.675     , 0.475     ],
#        [0.4625    , 0.3625    ],
#        [0.7875    , 0.5625    ],
#        [0.5875    , 0.5       ],
#        [0.35      , 0.275     ],
#        [0.7125    , 0.7625    ],
#        [0.8875    , 0.8125    ],
#        [0.6375    , 0.5625    ],
#        [0.6       , 0.4       ],
#        [0.825     , 0.75      ],
#        [0.85      , 0.7375    ],
#        [0.6125    , 0.525     ],
#        [0.375     , 0.4       ],
#        [0.55      , 0.425     ],
#        [0.7       , 0.425     ],
#        [0.45      , 0.7       ],
#        [0.5875    , 0.7125    ],
#        [0.4       , 0.4625    ],
#        [0.7625    , 0.725     ],
#        [0.5       , 0.525     ],
#        [0.9375    , 0.75      ],
#        [0.175     , 0.3       ],
#        [0.57954545, 0.54545455],
#        [0.4625    , 0.3       ],
#        [0.6375    , 0.725     ],
#        [0.51136364, 0.38636364],
#        [0.7375    , 0.525     ],
#        [0.8375    , 0.825     ]])

# %%
ypred_test_linear = loaded_model_linear.predict(features_test)
ypred_test_knn = loaded_model_knn.predict(features_test)
ypred_test_dectree = loaded_model_dectree.predict(features_test)

# %%
linear_mse = mean_squared_error(yactual_test, ypred_test_linear)
knn_mse = mean_squared_error(yactual_test, ypred_test_knn)
dectree_mse = mean_squared_error(yactual_test, ypred_test_dectree)
linear_rmse = sqrt(linear_mse)
knn_rmse = sqrt(knn_mse)
dectree_rmse = sqrt(dectree_mse)
print("RMSE linear regression: "+str(linear_rmse))
print("RMSE knn regression: "+str(knn_rmse))
print("RMSE decision tree regression: "+str(dectree_rmse))
# Out:
# RMSE linear regression: 0.13315530260077302
# RMSE knn regression: 0.13917546502849756
# RMSE decision tree regression: 0.15812598964705382

# %%
r2_linear_test = r2_score(yactual_test,ypred_test_linear)
r2_knn_test = r2_score(yactual_test, ypred_test_knn)
r2_dectree_test = r2_score(yactual_test, ypred_test_dectree)
print("R2 linear regression: "+str(r2_linear_test))
print("R2 knn regression: "+str(r2_knn_test))
print("R2 decision tree regression: "+str(r2_dectree_test))
# Out:
# R2 linear regression: 0.35683572539761993
# R2 knn regression: 0.29822853540852173
# R2 decision tree regression: 0.08951061761014883

# %%
ytest_pred = pd.DataFrame(yactual_test)
ytest_pred["pred_lin_aro(mean)"]=ypred_test_linear[:,0]
ytest_pred["pred_lin_val(mean)"]=ypred_test_linear[:,1]
ytest_pred["pred_knn_aro(mean)"]=ypred_test_knn[:,0]
ytest_pred["pred_knn_val(mean)"]=ypred_test_knn[:,1]
ytest_pred["pred_dectree_aro(mean)"]=ypred_test_dectree[:,0]
ytest_pred["pred_dectree_val(mean)"]=ypred_test_dectree[:,1]
ytest_pred
# Out:
#             0         1  pred_lin_aro(mean)  pred_lin_val(mean)  \
# 0    0.662500  0.650000            0.734299            0.739228
# 1    0.275000  0.350000            0.324653            0.360619
# 2    0.537500  0.837500            0.660297            0.585030
# 3    0.575000  0.625000            0.687614            0.643574
# 4    0.925000  0.862500            0.737581            0.714289
# ..        ...       ...                 ...                 ...
# 148  0.462500  0.300000            0.376544            0.474215
# 149  0.637500  0.725000            0.726367            0.673595
# 150  0.511364  0.386364            0.595782            0.589687
# 151  0.737500  0.525000            0.648025            0.670771
# 152  0.837500  0.825000            0.773371            0.690438
#
#      pred_knn_aro(mean)  pred_knn_val(mean)  pred_dectree_aro(mean)  \
# 0                0.7350              0.7450                  0.8125
# 1                0.4875              0.5400                  0.5125
# 2                0.7550              0.6975                  0.7125
# 3                0.7625              0.7225                  0.8625
# 4                0.7775              0.7750                  0.8875
# ..                  ...                 ...                     ...
# 148              0.3800              0.4675                  0.4250
# 149              0.7350              0.7700                  0.7375
# 150              0.5675              0.5850                  0.5500
# 151              0.8000              0.7325                  0.7875
# 152              0.7725              0.6875                  0.6500
#
#      pred_dectree_val(mean)
# 0                    0.7250
# 1                    0.3750
# 2                    0.6125
# 3                    0.7875
# 4                    0.8625
# ..                      ...
# 148                  0.3750
# 149                  0.6625
# 150                  0.5625
# 151                  0.7125
# 152                  0.6250
#
# [153 rows x 8 columns]

# %% [markdown]
# ### Scatter plot of data testing

# %%
import matplotlib.pyplot as plt
plt.xlim(0,1)
plt.ylim(0,1)
plt.axhline(y=0.5, color='black', linestyle='-')
plt.axvline(x=0.5, color='black', linestyle='-')
plt.xlabel("Arousal(mean)")
plt.ylabel("Valence(mean)")
plt.scatter(yactual_test[:,0],yactual_test[:,1],label="actual")
plt.scatter(ypred_test_linear[:,0],ypred_test_linear[:,1],label="linear")
plt.scatter(ypred_test_knn[:,0],ypred_test_knn[:,1],label="knn")
plt.scatter(ypred_test_dectree[:,0],ypred_test_dectree[:,1],label="decision_tree")
plt.legend()
plt.show()
